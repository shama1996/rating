# %%
#importing all the required libraries
import selenium
import pandas as pd
from selenium import webdriver # Importing selenium webdriver
import time

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
Rating=[]
Review=[]

# %%
search_list=['laptops', 'Phones', 'Headphones', 'smart watches', 'Professional Cameras', 'Printers', 'monitors', 
        'Home theater', 'router']

# %%
url2='https://www.amazon.com/'

# %%
for item in search_list:
    driver_1 = webdriver.Chrome(executable_path="C:\\Users\\HP\\chromedriver.exe")
    driver_1.get(url2)

    #Closing Pop-up
    #close_button=driver_1.find_element_by_xpath("//button[@class='_2KpZ6l _2doB4z']")
    #close_button.click()

    # searching required fields
    search_bar = driver_1.find_element_by_id("twotabsearchtextbox")    # Locating searc_bar by id                                              # clearing search_bar
    search_bar.send_keys(item) 

    search_button = driver_1.find_element_by_xpath('//span[@id="nav-search-submit-text"]/input')       # Locating search_button by xpath
    search_button.click()
    time.sleep(5)

    # Storing href links of each listing on first page
    links=driver_1.find_elements_by_xpath("//a[@class='a-link-normal a-text-normal']")
    for i in links[0:10]:
        driver_2=webdriver.Chrome(executable_path="C:\\Users\\HP\\chromedriver.exe")
        url=i.get_attribute('href')
        driver_2.get(url)
        # Opening full reviews
        #try:
        #    full=driver_2.find_element_by_xpath("//div[@class='a-section a-spacing-medium']/a")
        #except:
        #    continue
        #driver_3=webdriver.Chrome(executable_path="C:\\Users\\HP\\chromedriver.exe")
        #url=full.get_attribute('href')
        #driver_3.get(url) 
        #driver_2.close()
        
        
        link1=driver_2.find_elements_by_xpath("//a[@class='a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
        for i in link1:
            driver_3=webdriver.Chrome(executable_path="C:\\Users\\HP\\chromedriver.exe")
            url3=i.get_attribute('href')
            driver_3.get(url3)

            a=driver_3.find_element_by_xpath("//a[@class='a-link-normal']")
            Rating.append(a.get_attribute('title'))
            
            driver_3.close()
            

        #b=driver_2.find_elements_by_xpath("//div[@class='a-section review aok-relative']/div/div/div[4]/span/div")
        #for k in b:
           # Review.append(k.text)
            
        
        #a=driver_2.find_elements_by_xpath("//div[@class='a-section review aok-relative']/div/div/div[2]/a/i/span")
        #for j in a:
           # Rating.append(j.text)    

        driver_2.close()

    driver_1.close()

# %%
#Rating
# Out:
# ['1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '5.0 out of 5 stars',
# ...

# %%
#len(Rating)
# Out:
# 546

# %%
url1='https://www.amazon.com/'

# %%
for item in search_list:
    driver_1 = webdriver.Chrome(executable_path="C:\\Users\\HP\\chromedriver.exe")
    driver_1.get(url1)

    #Closing Pop-up
    #close_button=driver_1.find_element_by_xpath("//button[@class='_2KpZ6l _2doB4z']")
    #close_button.click()

    # searching required fields
    search_bar = driver_1.find_element_by_id("twotabsearchtextbox")    # Locating searc_bar by id                                              # clearing search_bar
    search_bar.send_keys(item) 

    search_button = driver_1.find_element_by_xpath('//span[@id="nav-search-submit-text"]/input')       # Locating search_button by xpath
    search_button.click()
    time.sleep(5)

    # Storing href links of each listing on first page
    links=driver_1.find_elements_by_xpath("//a[@class='a-link-normal a-text-normal']")
    for i in links[0:10]:
        driver_2=webdriver.Chrome(executable_path="C:\\Users\\HP\\chromedriver.exe")
        url=i.get_attribute('href')
        driver_2.get(url)
        # Opening full reviews
        #try:
        #    full=driver_2.find_element_by_xpath("//div[@class='a-section a-spacing-medium']/a")
        #except:
        #    continue
        #driver_3=webdriver.Chrome(executable_path="C:\\Users\\HP\\chromedriver.exe")
        #url=full.get_attribute('href')
        #driver_3.get(url) 
        #driver_2.close()

          

        b=driver_2.find_elements_by_xpath("//div[@class='a-section review aok-relative']/div/div/div[4]/span/div")
        for k in b:
            Review.append(k.text)
            
        
        #a=driver_2.find_elements_by_xpath("//div[@class='a-section review aok-relative']/div/div/div[2]/a/i/span")
        #for j in a:
           # Rating.append(j.text)    

        driver_2.close()

    driver_1.close()

# %%
Rating
# Out:
# ['1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '5.0 out of 5 stars',
# ...

# %%
len(Rating)
# Out:
# 546

# %%
Review
# Out:
# ["Pros and Cons. But I think it's a cool laptop.\n\nPros:\n- Speaker placement is superb (right above the keyboard)\n- Screen is decent (720p but I don't mind)\n- Keyboard is decent\n- Has one USB C port and sever legacy ports (hdmi, 2x USB A, SD card slot, headphone port) Awesome versatility!\n\nCons:\n- Trackpad stops working for almost a minute, at least once every hour or two. I usually put the laptop to sleep and then I wake it up again and that resolves it. However, it's not worth the trouble.\n- Sometimes the brightness buttons don't work. Neither does the brightness slider on Windows either. So the screen stays at a consistent brightness.\n\nI like this laptop but I must return it. Trackpad is important to me, especially for working on the go.\n\nEvery unit might provide a different experience. Maybe the next unit I purchase will be better and have no remarkable flaws but I won't take that chance. I'll get one from Lenovo for around the same price.\nRead more",
# ...

# %%
len(Review)
# Out:
# 527

# %%
New_Rating=[]
New_Rating=Rating[0:527]

# %%
New_Rating
# Out:
# ['1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '5.0 out of 5 stars',
# ...

# %%
len(New_Rating)
# Out:
# 527

# %%
URL1='https://www.flipkart.com/'

# %%
#creating a loop where elements from search_list will be taken
for item in search_list:
    driver_1 = webdriver.Chrome(executable_path="C:\\Users\\HP\\chromedriver.exe")
    driver_1.get(URL1)

    #Closing the Pop-up button appearing on the page
    close_button=driver_1.find_element_by_xpath("//button[@class='_2KpZ6l _2doB4z']")
    close_button.click()

    # searching required fields i.e., giving the path of search bar and passing item as "keys"
    search=driver_1.find_element_by_xpath("//div[@class='_3OO5Xc']/input")
    search.send_keys(item)

    
    search_button=driver_1.find_element_by_xpath("//button[@class='L0Z3Pu']")
    search_button.click() #clicking on the search button
    time.sleep(5)

    # Storing href links of each listing on first page
    links=driver_1.find_elements_by_xpath("//a[@class='_1fQZEK']")
    for i in links:
        driver_2=webdriver.Chrome(executable_path="C:\\Users\\HP\\chromedriver.exe")
        url=i.get_attribute('href')
        driver_2.get(url)
        # Opening full reviews of the paticular product in that item
        try:
            full=driver_2.find_element_by_xpath("//div[@class='col JOpGWq']/a")
        except:
            continue
        driver_3=webdriver.Chrome(executable_path="C:\\Users\\HP\\chromedriver.exe")
        url=full.get_attribute('href')
        driver_3.get(url) 
        driver_2.close()


        a=driver_3.find_elements_by_xpath("//div[@class='col']/div/div[1]/div") #searching for rating path
        for j in a[2:]:
            New_Rating.append(j.text) #appending the elements in Rating list

        a=driver_3.find_elements_by_xpath("//div[@class='t-ZTKy']/div/div") #searching for review path
        for k in a:
            Review.append(k.text) #appending the elements in Review list

        driver_3.close()

    driver_1.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-cb4c929eaf9c> in <module>
#       1 #creating a loop where elements from search_list will be taken
#       2 for item in search_list:
# ----> 3     driver_1 = webdriver.Chrome(executable_path="C:\\Users\\HP\\chromedriver.exe")
#       4     driver_1.get(URL1)
#       5
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\chrome\webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, keep_alive)
#      74
#      75         try:
# ---> 76             RemoteWebDriver.__init__(
#      77                 self,
#      78                 command_executor=ChromeRemoteConnection(
#
# ...

# %%
New_Rating
# Out:
# ['1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '5.0 out of 5 stars',
# ...

# %%
Review
# Out:
# ["Pros and Cons. But I think it's a cool laptop.\n\nPros:\n- Speaker placement is superb (right above the keyboard)\n- Screen is decent (720p but I don't mind)\n- Keyboard is decent\n- Has one USB C port and sever legacy ports (hdmi, 2x USB A, SD card slot, headphone port) Awesome versatility!\n\nCons:\n- Trackpad stops working for almost a minute, at least once every hour or two. I usually put the laptop to sleep and then I wake it up again and that resolves it. However, it's not worth the trouble.\n- Sometimes the brightness buttons don't work. Neither does the brightness slider on Windows either. So the screen stays at a consistent brightness.\n\nI like this laptop but I must return it. Trackpad is important to me, especially for working on the go.\n\nEvery unit might provide a different experience. Maybe the next unit I purchase will be better and have no remarkable flaws but I won't take that chance. I'll get one from Lenovo for around the same price.\nRead more",
# ...

# %%
len(New_Rating)
# Out:
# 1027

# %%
len(Review)
# Out:
# 1027

# %%
df=pd.DataFrame({})
df['Rating']=New_Rating
df['Review']=Review
df
# Out:
#                   Rating                                             Review
# 0     1.0 out of 5 stars  Pros and Cons. But I think it's a cool laptop....
# 1     5.0 out of 5 stars  Just opened, I'm sure the computer is great, b...
# 2     5.0 out of 5 stars  The Microsoft Office was only free for 30 days...
# 3     4.0 out of 5 stars  This computer is NOT for gaming or gamers. It ...
# 4     1.0 out of 5 stars  Perfect size. Not too big or small. Very fast ...
# ...                  ...                                                ...
# 1022                   4  Pros:-\n1. The Watch has great battery life ca...
# 1023                   5  I have been using this watch since 14 days. Ba...
# 1024                   4  PROS : GOOD BATTERY LIFE 🔋\nAmazing touch feed...
# 1025                   4  This was my first smartwatch, and I was very e...
# 1026                   4  Watch is good after the update please try to g...
#
# [1027 rows x 2 columns]

# %%
df.to_csv('Ratings_Prediction_Data_New')
